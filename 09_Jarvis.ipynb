# %% [markdown]
# # Projekt *"JARVIS"*
#
# ## Import knihoven

# %%
import speech_recognition as sr

from gtts import gTTS
import pyttsx

import pygame
import IPython

# %% [markdown]
# ## Jarvis’s Mouth: Text-to-Speech (převod textu na řeč)

# %%
def spaceitout(source):
    spacenum = ""
    for letter in source:
        spacenum = spacenum + letter + " "
    spacenum = spacenum[:-1]
    
    return spacenum

number = input("Vlož číslo: ")

spacenum = spaceitout(number)

message = "Zadal jsi číslo: "+str(spacenum)+"."

tts = gTTS(message, lang='cs')
tts.save("sound.mp3")

pygame.mixer.init(24000)
pygame.mixer.music.load("sound.mp3")
pygame.mixer.music.play()

while pygame.mixer.music.get_busy() == True:
    continue

print("Hotovo...")

IPython.display.Audio("sound.mp3")
# Out:
# Vlož číslo: 173404
# Hotovo...
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
M = input("Napiš něco veselého: ")
M = str(M)

tts = gTTS(M, lang='cs')
tts.save("sound.mp3")

pygame.mixer.init(24000)
pygame.mixer.music.load("sound.mp3")
pygame.mixer.music.play()

while pygame.mixer.music.get_busy() == True:
    continue

print("\nHotovo...")

IPython.display.Audio("sound.mp3")
# Out:
# Napiš něco veselého: Osobní číslo 1 7 3 4 0 4 patří zaměstnanci jménem Miroslav Burda. Miroslav pracuje od čtvrtého prosince roku 2015 na středisku 108.
#
# Hotovo...
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
M = input("Napiš něco veselého: ")
M = str(M)

engine = pyttsx.init()

engine.setProperty('rate', 150)
engine.setProperty('voice','cs')

engine.say(M)

engine.runAndWait()
# Out:
# Napiš něco veselého: Osobní číslo 1 7 3 4 0 4 patří zaměstnanci jménem Miroslav Burda. Miroslav pracuje od čtvrtého prosince roku 2015 na středisku 108.

# %% [markdown]
# ## Jarvis’s Ears: Speech Recognition (převod řeči na kód)
# ### Převod řeči na text a NLP *(Natural Language Processing)*

# %%
## NaN

# %% [markdown]
# ## Jarvis’s Brain: The Code (logika projektu)

# %%
## NaN
